# %% [markdown]
# 안녕하세요. 수강생 여러분~!
#
# 다시 돌아온 조금 더 성장할 기 ! 회 !
#
# Chapter01 ~ 16의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다 !
#
# 지금까지 잘 해오셨으니까, 총 복습한다고 생각하시고 한번 도전해보세요 !!!
#
# 차근 차근 문제와 요구사항을 읽고 작성해보세요.
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# #### 프로젝트: 붕어빵 자동 판매 시스템
#
#
# 당신은 붕어빵 가게의 주인입니다.
#
# 손님들이 붕어빵을 주문하면 이를 자동으로 처리하고, 재고를 관리하는 시스템을 만들고자 합니다.
#
# 또한, 관리자 모드를 통해 재고를 추가할 수 있는 기능을 구현해야 합니다.

# %% [markdown]
# __[문제 1: 붕어빵 재고 확인]__
#
# 붕어빵 가게의 현재 재고를 확인하는 기능을 구현하세요.
#
# 요구사항:
# - 현재 붕어빵의 재고를 딕셔너리로 관리합니다.
# - 딕셔너리에는 붕어빵의 종류와 각각의 재고 개수가 저장됩니다.
# - 현재 재고를 화면에 출력하세요.
#
# 붕어빵 재고
# - 팥붕어빵 : 10개
# - 슈크림붕어빵 : 8개
# - 초코붕어빵 : 5개

# %%
현재재고 = {
    "red_bean":10,
    "cream":8,
    "choco":5
}

for k,n in 현재재고.items():
    print(f"{k}: {n}")
# Out:
# red_bean: 10
# cream: 8
# choco: 5

# %% [markdown]
# __[문제 2: 붕어빵 주문 받기]__
#
# 손님이 주문한 붕어빵의 종류와 개수를 입력받는 기능을 구현하세요.
#
# 요구사항:
# - 손님이 주문할 붕어빵의 종류와 개수를 입력받습니다.
# - 주문 내용을 딕셔너리에 저장하세요.
# - 주문 내역을 출력해주세요.

# %%
order_book = {}


red_bean = int(input("팥"))
cream = int(input("슈크림"))
choco = int(input("초코"))

order_book["red_bean"] = red_bean
order_book["cream"] = cream
order_book["choco"] = choco


print(order_book)

# %% [markdown]
# __[문제 3: 붕어빵 주문 처리]__
#
# 손님의 주문을 처리하여 붕어빵 재고를 업데이트하는 기능을 구현하세요.
#
# 요구사항:
# - 손님의 주문 내용을 기반으로 재고를 업데이트합니다.
# - 재고가 부족할 경우, 손님에게 재고 부족을 알리고 재고를 감소시키지 않습니다.
# - 재고가 충분할 경우, 주문한 만큼 재고를 감소시키고 판매를 완료합니다.
# - 판매가 완료된 경우 판매된 붕어빵 맛과 개수를 출력하세요.

# %%
for k in 현재재고:
    if 현재재고[k] < order_book[k]:
        print(f"당신의 주문개수 {k}:{order_book[k]} 가 우리의 재고 {k}{현재재고[k]} 보다 많습니다")
        
    else:
        print(f"{k}붕어빵이 {order_book[k]}만큼 판매 되었습니다.")
        현재재고[k] -= order_book[k]


print(현재재고)

# %% [markdown]
# __[문제 4: 여러 손님 주문 처리]__
#
# 여러 손님들의 주문을 처리할 수 있도록 시스템을 확장하세요.
#
# 요구사항:
# - 손님이 "종료"를 입력할 때까지 주문을 계속 받습니다.
# - 각 주문마다 재고를 업데이트합니다.
# - 현재 재고를 화면에 출력합니다.

# %%
현재재고 = {
    "red_bean":10,
    "cream":8,
    "choco":5
}

order_book ={}

종료 = 0

while  sum(현재재고.values())>0 and 종료 ==0 :
    order_on_off = input("종료 여부를 알려주세요 종료하고 싶으면 종료 아니며 엔터를 눌러주세요")
    

    if order_on_off =="종료":
        종료 +=1
        break
        

    red_bean = int(input("팥 구매하고싶지 않으시면 0을 입력해 주세요"))
    cream = int(input("슈크림 구매하고싶지 않으시면 0을 입력해 주세요"))
    choco = int(input("초코 구매하고싶지 않으시면 0을 입력해 주세요"))

        

    order_book["red_bean"] = red_bean
    order_book["cream"] = cream
    order_book["choco"] = choco

    for k in 현재재고:
    
        if 현재재고[k] < order_book[k]:
            print(f"당신의 주문개수 {k}:{order_book[k]} 가 우리의 재고 {k}{현재재고[k]} 보다 많습니다")
        
        else:
            
            현재재고[k] -= order_book[k]
            print(f"{k}붕어빵이 {order_book[k]}만큼 판매 되었습니다.")
        
    print(현재재고)
# Out:
# red_bean붕어빵이 1만큼 판매 되었습니다.
# cream붕어빵이 1만큼 판매 되었습니다.
# choco붕어빵이 1만큼 판매 되었습니다.
# {'red_bean': 9, 'cream': 7, 'choco': 4}
# red_bean붕어빵이 -1만큼 판매 되었습니다.
# cream붕어빵이 1만큼 판매 되었습니다.
# choco붕어빵이 1만큼 판매 되었습니다.
# {'red_bean': 10, 'cream': 6, 'choco': 3}

# %% [markdown]
# __[문제 5: 관리자 모드]__
#
# 관리자 모드를 통해 붕어빵 재고를 추가할 수 있는 기능을 구현하세요.
#
# 요구사항:
# - 관리자는 특정 붕어빵의 재고를 추가할 수 있습니다.
# - "종료"를 입력하면 관리자 모드를 종료합니다.
# - 추가된 재고를 업데이트하고 현재 재고를 화면에 출력합니다.

# %%
admin_mode =input()

kill_admin_mode = 0


while admin_mode == "관리자 모드" and kill_admin_mode ==0:
    
    admin_mode_on_off =input("종료 하고싶으시면 '종료' 그게 아니라면 '엔터'를 눌러주세요 ")

    if admin_mode_on_off =="종료":
        kill_admin_mode +=1
        
    else:

        red_bean = int(input("red_bean"))
        cream = int(input("cream"))
        choco = int(input("choco"))

    
        현재재고["red_bean"] += red_bean
        현재재고["cream"] += cream
        현재재고["choco"] += choco

       
    
        print(현재재고)
# Out:
# {'red_bean': 18, 'cream': 16, 'choco': 13}
# {'red_bean': 19, 'cream': 17, 'choco': 14}
# {'red_bean': 20, 'cream': 18, 'choco': 15}

# %% [markdown]
# __[문제 6: 매출 확인]__
#
# 붕어빵 판매 가격을 설정하고, 판매한 붕어빵의 매출을 계산하세요.
#
# 요구사항:
# - 각 붕어빵의 가격을 딕셔너리로 관리합니다.
# - 판매된 붕어빵의 종류와 개수를 딕셔너리로 관리합니다.
# - 총 매출을 계산하여 출력합니다.
#
# 초기 설정:
# - 가격
#     - "팥붕어빵": 1000
#     - "슈크림붕어빵": 1200
#     - "초코붕어빵": 1500
#
# - 판매 개수
#     - "팥붕어빵": 0
#     - "슈크림붕어빵": 0
#     - "초코붕어빵": 0

# %%
현재재고 = {
    "red_bean":10,
    "cream":8,
    "choco":5
}

order_book ={}



sell_recode = {
    "red_bean":0,
    "cream":0,
    "choco":0,
}



fish_b_price = {
    "red_bean":1000,
    "cream":1200,
    "choco":1500,
}


종료 = 0

while  sum(현재재고.values())>0 and 종료 ==0 :
    order_on_off = input("종료 여부를 알려주세요 종료하고 싶으면 종료 아니며 엔터를 눌러주세요")
    

    if order_on_off =="종료":
        종료 +=1
        break
        

    red_bean = int(input("팥 구매하고싶지 않으시면 0을 입력해 주세요"))
    cream = int(input("슈크림 구매하고싶지 않으시면 0을 입력해 주세요"))
    choco = int(input("초코 구매하고싶지 않으시면 0을 입력해 주세요"))

        

    order_book["red_bean"] = red_bean
    order_book["cream"] = cream
    order_book["choco"] = choco

    for k in 현재재고:
    
        if 현재재고[k] < order_book[k]:
            print(f"당신의 주문개수 {k}:{order_book[k]} 가 우리의 재고 {k}{현재재고[k]} 보다 많습니다")
        
        else:
            
            현재재고[k] -= order_book[k]
            sell_recode[k]+=order_book[k]
           
            
            total_selling_money += 


            print(f"{k}붕어빵이 {order_book[k]}만큼 판매 되었습니다.")
        
    print(현재재고)


total_sell ={
    "red_bean":order_book["red_bean"]*fish_b_price['red_bean'],
    "cream":order_book["cream"]*fish_b_price['cream'],
    "choco":order_book["choco"]*fish_b_price['choco']
}

print(f"팥 붕어빵 : {order_book['red_bean']} 금액:{total_sell['red_bean']}")
print(f"크림 붕어빵 : {order_book['cream']} 금액:{total_sell['cream']}")
print(f"초코 붕어빵 : {order_book['choco']} 금액:{total_sell['choco']}")
print(f"총 :{sum(total_sell.values())}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[145], line 63
#      57         sell_recode[k]+=order_book[k]
#      58         total_sell ={
#      59     "red_bean":order_book["red_bean"]*fish_b_price['red_bean'],
#      60     "cream":order_book["cream"]*fish_b_price['cream'],
#      61     "choco":order_book["choco"]*fish_b_price['choco']
#      62         }
# ---> 63         total_selling_money += total_sell
#      66         print(f"{k}붕어빵이 {order_book[k]}만큼 판매 되었습니다.")
#      68 print(현재재고)
#
# TypeError: unsupported operand type(s) for +=: 'dict' and 'dict'

# %%
# Out:
# {'red_bean': 4, 'cream': 4, 'choco': 4}
